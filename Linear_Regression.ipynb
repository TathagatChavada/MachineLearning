# %% [markdown]
# <a href="https://colab.research.google.com/github/TathagatChavada/MachineLearning/blob/main/Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Linear Regression from Scratch**

# %%
# !pip3 install matplotlib
# !pip3 install numpy
# !pip3 install pandas

# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd

# %%
# Set seed for reproducibility
# Set seed for reproducibility
np.random.seed(42)

# Generate random integer data for x and y
x = np.random.randint(20, 91, size=100)  # 100 data points between 20 and 90
y = 3 * x + np.random.randint(-10, 11, size=100)  # Assuming a linear relationship with some random noise

# Plot the generated data
plt.scatter(x, y, label='Generated Data')

# Add labels and title
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Linear Regression Data Generation')

# Add legend
plt.legend()

# Show the plot
plt.show()

# %%
def gradient_descent(current_m, current_b, x, y, learning_rate):

    m_gradient = 0
    b_gradient = 0

    n = len(x)

    for i in range(n):
        m_gradient = -(2/n) * x[i] * (y[i] - (current_m * x[i] + current_b))
        b_gradient = -(2/n) * (y[i] - (current_m * x[i] + current_b))


    m = current_m - m_gradient * learning_rate
    b = current_b - b_gradient * learning_rate

    return m, b

# %%
m, b = 0,0

learning_rate = 0.0001
epochs = 1000


for i in range(epochs):

    if (i % 100 == 0):
        print(f"Epoch: {i}")

    m, b = gradient_descent(m, b, x, y, learning_rate)


print(f"Slope: {m} , Interscept: {b}")

plt.scatter(x, y, label='Generated Data')
plt.plot(list(range(20, 90)), [m * x + b for x in range(20,90)], color="red")
plt.show()
# Out:
# Epoch: 0
# Epoch: 100
# Epoch: 200
# Epoch: 300
# Epoch: 400
# Epoch: 500
# Epoch: 600
# Epoch: 700
# Epoch: 800
# Epoch: 900
# Slope: 2.9685459321424834 , Interscept: 0.044977968668825516
